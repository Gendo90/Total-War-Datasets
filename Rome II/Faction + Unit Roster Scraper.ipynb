# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
import datetime
import pandas as pd
import lxml

# %%
# utility functions 

# gets alt tags for images that are otherwise given in table as NaN, for levels and country
def getAlt(x):
    for img in x.find_all('img'):
        if(img.get("alt")):
#             print(img.get("alt"))
            img.string = img.get("alt")
    
def getLinkData(x):
    for a in x.find_all('a'):
        getAlt(a)
        
# gets the table data from the raw scraping, organizing lists of data for the icons and links
def getTableData(row):
    if('tr_header' in row.get_attribute_list('class')):
        return row.td.get_text()
    results = []
    for div in row.find_all('div'):
        a = div.find('a')
        img = a.find('img')
        val = {
            "link": a.get('href'),
            "text": a.get_text(),
            "image": img.get('src')
        }
        results.append(val)
        
    return results
            
# reorganizes the raw scraped data into a list of dictionaries
# with identical keys (to become columns)
def collapseHeaderRows(row_list, condensor_str):
    i = 0
    curr_grouping = row_list[i]
    updated_data_list = []
    while(i < len(row_list)):
        if(row_list[i] == str(row_list[i])):
            curr_grouping = row_list[i]
            row_list.remove(curr_grouping)
        else:
            for j in range(len(row_list[i])):
                row_list[i][j][condensor_str] = curr_grouping
                updated_data_list.append(row_list[i][j])
            i += 1
                
    return updated_data_list
        
# creates a DF from the reorganized data, with custom names for
# the values to combine (from the "header" row above the list of items in the table) and
# the "text" of those items (may be "Factions", "Unit Types", etc.)
def createDFfromRowData(row_data, condensor_str, text_name):
    header = row_data.pop(0)
    row_data_condensed = collapseHeaderRows(row_data, condensor_str)

    return pd.DataFrame(data={
        condensor_str:[a[condensor_str] for a in row_data_condensed],
        text_name: [a["text"] for a in row_data_condensed],
        "link": [a["link"] for a in row_data_condensed],
        "image": [a["image"] for a in row_data_condensed],
    })

# %%
# start by getting data for each playable faction, then add unit scraping on top of it (helper function later)
def getFactionsData():
    url = "https://www.honga.net/totalwar/rome2/?l=en&v=rome2"

    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=False)

    browser.visit(url)
    
    #add a delay so page fully loads
    time.sleep(6)
    
    factions = []
    
    try:
        current_leaderboard = browser.html

        news_soup = bs(current_leaderboard, "html.parser")

        playable_factions = news_soup.find_all("table")[0]


        
        for i, row in enumerate(playable_factions.find_all('tr')):
            val = row.get_text().strip()
            if(not i == 0):
                val = getTableData(row)
            factions.append(val)
            
    except:
        print("Something went wrong!")
        
    
    browser.quit()

    return factions
# Out:
#   File "<ipython-input-93-361ccae8bd16>", line 33
#     browser.quit()
#           ^
# IndentationError: expected an indented block

# %%
#get basic playable faction data (by scraping honga.net)
output_df = getFactionsData()

output_df
# Out:
# ['Playable Factions',
#  'Grand Campaign',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_ardiaei',
#    'text': 'Ardiaei',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/ardiaei/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_arevaci',
#    'text': 'Arevaci',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/arevaci/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_armenia',
#    'text': 'Armenia',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/armenia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_arverni',
#    'text': 'Arverni',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/arverni/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_athens',
#    'text': 'Athens',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/athens/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_baktria',
#    'text': 'Baktria',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/baktria/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_boii',
#    'text': 'Boii',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/boii/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_carthage',
#    'text': 'Carthage',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/carthage/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_cimmeria',
#    'text': 'Cimmeria',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/cimmeria/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_colchis',
#    'text': 'Colchis',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/colchis/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_ptolemaics',
#    'text': 'Egypt',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/egypt/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_epirus',
#    'text': 'Epirus',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/epirus/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_galatia',
#    'text': 'Galatia',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/galatia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_getae',
#    'text': 'Getae',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/getae/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_iceni',
#    'text': 'Iceni',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/iceni/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_kush',
#    'text': 'Kush',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/meroe/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_lusitani',
#    'text': 'Lusitani',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/lusitani/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_macedon',
#    'text': 'Macedon',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/macedon/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_masaesyli',
#    'text': 'Masaesyli',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/masaesyli/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_massagetae',
#    'text': 'Massagetae',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/massagetae/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_massilia',
#    'text': 'Massilia',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/massilia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_nabatea',
#    'text': 'Nabataea',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/nabatea/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_nervii',
#    'text': 'Nervii',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/nervii/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_odryssia',
#    'text': 'Odrysian Kingdom',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/odryssian%20kingdom/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_parthia',
#    'text': 'Parthia',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/parthia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_pergamon',
#    'text': 'Pergamon',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/pergamon/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_pontus',
#    'text': 'Pontus',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/pontus/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_rome',
#    'text': 'Rome',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_roxolani',
#    'text': 'Roxolani',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/roxolani/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_scythia',
#    'text': 'Royal Scythia',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/royal%20scythia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_saba',
#    'text': 'Saba',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/saba/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_seleucid',
#    'text': 'Seleucid',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/seleucid/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_sparta',
#    'text': 'Sparta',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/sparta/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_suebi',
#    'text': 'Suebi',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/suebi/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_syracuse',
#    'text': 'Syracuse',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/syracuse/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=rom_tylis',
#    'text': 'Tylis',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/tylis/mon_64.png'}],
#  'Samnite Wars',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pro_rome',
#    'text': 'Rome (Samnite Wars)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome/mon_64.png'}],
#  'Caesar in Gaul',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=gaul_arverni',
#    'text': 'Arverni (Caesar in Gaul)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/arverni/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=gaul_nervii',
#    'text': 'Nervii (Caesar in Gaul)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/nervii/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=gaul_rome',
#    'text': 'Rome (Caesar in Gaul)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=gaul_suebi',
#    'text': 'Suebi (Caesar in Gaul)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/suebi/mon_64.png'}],
#  'Hannibal at the Gates',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pun_arevaci',
#    'text': 'Arevaci (Hannibal at the Gates)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/arevaci/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pun_carthage',
#    'text': 'Carthage (Hannibal at the Gates)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/carthage/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pun_lusitani',
#    'text': 'Lusitani (Hannibal at the Gates)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/lusitani/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pun_rome',
#    'text': 'Rome (Hannibal at the Gates)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pun_syracuse',
#    'text': 'Syracuse (Hannibal at the Gates)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/syracuse/mon_64.png'}],
#  'Imperator Augustus',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_antony',
#    'text': "Antony's Rome (Imperator Augustus)",
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome_antony/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_armenia',
#    'text': 'Armenia (Imperator Augustus)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/armenia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_dacia',
#    'text': 'Dacia (Imperator Augustus)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/getae/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_egypt',
#    'text': 'Egypt (Imperator Augustus)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/egypt/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_iceni',
#    'text': 'Iceni (Imperator Augustus)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/iceni/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_lepidus',
#    'text': "Lepidus' Rome (Imperator Augustus)",
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome_lepidus/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_marcomanni',
#    'text': 'Marcomanni (Imperator Augustus)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/marcomanni/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_octavian',
#    'text': "Octavian's Rome (Imperator Augustus)",
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome_octavian/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_parthia',
#    'text': 'Parthia (Imperator Augustus)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/parthia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=emp_pompey',
#    'text': "Pompey's Rome (Imperator Augustus)",
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/rome_pompey/mon_64.png'}],
#  'Wrath of Sparta',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pel_athenai',
#    'text': 'Athenai (Wrath of Sparta)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/athens/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pel_boiotia',
#    'text': 'Boiotian League (Wrath of Sparta)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/boiotian_league/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pel_korinthos',
#    'text': 'Korinthos (Wrath of Sparta)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/korinthos/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=pel_sparta',
#    'text': 'Sparta (Wrath of Sparta)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/sparta/mon_64.png'}],
#  'Empire Divided',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_alani',
#    'text': 'Alani (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_alani/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_armenia',
#    'text': 'Armenia (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/armenia/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_caledoni',
#    'text': 'Caledonii (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_caledones/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_gallicemp',
#    'text': 'Gallic Rome (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_gallic_empire/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_gothi',
#    'text': 'Gothi (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_gothic/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_marcomanni',
#    'text': 'Marcomanni (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/marcomanni/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_palmyra',
#    'text': 'Palmyra (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_palmyrene_empire/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_rome',
#    'text': 'Rome (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_roman_empire_2/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_sassanid',
#    'text': 'The Sassanids (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_sassanid/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=3c_saxoni',
#    'text': 'Saxoni (Empire Divided)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/3c_saxons/mon_64.png'}],
#  'Rise of the Republic',
#  [{'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_insubres',
#    'text': 'Insubres (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/insubres/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_iolei',
#    'text': 'Iolei (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/inv_balari/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_rome',
#    'text': 'Rome (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/inv_rome/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_samnites',
#    'text': 'Samnites (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/samnites/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_senones',
#    'text': 'Senones (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/senones/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_syracuse',
#    'text': 'Syracuse (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/syracuse/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_taranto',
#    'text': 'Taras (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/inv_taranto/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_tarchuna',
#    'text': 'Tarchuna (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/inv_tarchuna/mon_64.png'},
#   {'link': 'https://www.honga.net/totalwar/rome2/faction.php?l=en&v=rome2&f=inv_veneti',
#    'text': 'Veneti (Rise of the Republic)',
#    'image': 'https://www.honga.net/totalwar/rome2/images/rome2/flags/veneti/mon_64.png'}]]

# %%
factions = output_df.copy()
check_df = createDFfromRowData(factions, "Campaign", "Faction")
check_df.to_csv("./output/Factions.csv", index=False)
check_df
# Out:
#                 Campaign                          Faction  \
# 0         Grand Campaign                          Ardiaei
# 1         Grand Campaign                          Arevaci
# 2         Grand Campaign                          Armenia
# 3         Grand Campaign                          Arverni
# 4         Grand Campaign                           Athens
# ..                   ...                              ...
# 74  Rise of the Republic   Senones (Rise of the Republic)
# 75  Rise of the Republic  Syracuse (Rise of the Republic)
# 76  Rise of the Republic     Taras (Rise of the Republic)
# 77  Rise of the Republic  Tarchuna (Rise of the Republic)
# 78  Rise of the Republic    Veneti (Rise of the Republic)
#
#                                                  link  \
# 0   https://www.honga.net/totalwar/rome2/faction.p...
# 1   https://www.honga.net/totalwar/rome2/faction.p...
# 2   https://www.honga.net/totalwar/rome2/faction.p...
# 3   https://www.honga.net/totalwar/rome2/faction.p...
# 4   https://www.honga.net/totalwar/rome2/faction.p...
# ..                                                ...
# 74  https://www.honga.net/totalwar/rome2/faction.p...
# 75  https://www.honga.net/totalwar/rome2/faction.p...
# 76  https://www.honga.net/totalwar/rome2/faction.p...
# 77  https://www.honga.net/totalwar/rome2/faction.p...
# 78  https://www.honga.net/totalwar/rome2/faction.p...
#
#                                                 image
# 0   https://www.honga.net/totalwar/rome2/images/ro...
# 1   https://www.honga.net/totalwar/rome2/images/ro...
# 2   https://www.honga.net/totalwar/rome2/images/ro...
# 3   https://www.honga.net/totalwar/rome2/images/ro...
# 4   https://www.honga.net/totalwar/rome2/images/ro...
# ..                                                ...
# 74  https://www.honga.net/totalwar/rome2/images/ro...
# 75  https://www.honga.net/totalwar/rome2/images/ro...
# 76  https://www.honga.net/totalwar/rome2/images/ro...
# 77  https://www.honga.net/totalwar/rome2/images/ro...
# 78  https://www.honga.net/totalwar/rome2/images/ro...
#
# [79 rows x 4 columns]
